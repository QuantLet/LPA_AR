# %%
#Importing packages
import pandas as pd
import io
from math import sqrt
import matplotlib.pyplot as plt 
import numpy as np
from datetime import datetime
from scipy import stats
import math
from sklearn.metrics import mean_squared_error
from decimal import Decimal
import timeit

from concurrent.futures import ProcessPoolExecutor
import os

## Setting defaults for plots
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 400
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['font.size'] = 15
plt.rcParams['legend.fontsize'] = 30
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['axes.linewidth'] = 2

# %%
def generate_random_weights(num):
    return np.random.exponential(1, num)

def weights_matrix(num, length):
    weights = [generate_random_weights(length) for _ in range(num)]
    return np.array(weights).T

def R(x,w): 
    # To store the required sum 
    s = 0; 
    n = len(x)
    for i in range(0,n): 
        # Add factorial of all the elements 
        s += math.lgamma(x[i]+1) * w[i];
        #s += math.log(math.factorial(x[i]))*w[i]; 
    return s

# For stepwise function plot
def mystep(x,y,z, ax=None, **kwargs):
    x = np.array(x)
    y = np.array(y)
    z = np.array(z)
    X = np.c_[x[:-1],x[1:],x[1:]]
    Y = np.c_[y[:-1],y[:-1],np.zeros_like(x[:-1])*np.nan]
    Z = np.c_[z[:-1],z[:-1],np.zeros_like(x[:-1])*np.nan]
    plt.figure(figsize=(15,8))
    if not ax: ax=plt.gca()
    ax.plot(X.flatten(), Z.flatten(), **kwargs)
    return ax.plot(X.flatten(), Y.flatten(), **kwargs)

def Likelihood(theta, x, p=3, w=None):
    """
    Compute the (possibly weighted) log-likelihood of an AR(p) process with Gaussian noise.

    Parameters:
        theta (array): Parameter vector [phi_1, ..., phi_p, sigma2]
        x (array): Time series data
        p (int): Order of AR process
        w (array or None): Optional weights for each residual (length = len(x) - p)

    Returns:
        log_likelihood (float): The log-likelihood of the AR(p) model
    """
    phi = np.array(theta[:p])
    sigma2 = theta[p]

    if sigma2 <= 0:
        return -np.inf

    T = len(x)
    if T <= p:
        raise ValueError("Time series length must be greater than AR order p.")
    
    residuals = np.array([
        x[t] - np.dot(phi, x[t-p:t][::-1])
        for t in range(p, T)
    ])

    n = T - p

    # Default to equal weights if none provided
    if w is None:
        w = np.ones(n)
    else:
        w = w[:-p]

    log_density = -0.5 * np.log(2 * np.pi * sigma2) - 0.5 * residuals**2 / sigma2
    logL = np.sum(w * log_density)

    return logL

def MLE_estimator(x, p=3, w=None, return_stats=False):
    x = np.asarray(x)
    T = len(x)

    if T <= p:
        raise ValueError("Time series length must be greater than AR order p.")

    y = x[p:]
    X = np.column_stack([x[p - i - 1:T - i - 1] for i in range(p)])

    if w is None:
        w = np.ones(T)
    w = np.asarray(w)[p:]

    if len(w) != len(y):
        raise ValueError("Weights length does not match target vector length.")

    W = np.diag(w)
    XtWX = X.T @ W @ X
    XtWy = X.T @ W @ y

    phi_hat = np.linalg.solve(XtWX, XtWy)

    residuals = y - X @ phi_hat
    sigma2_hat = np.sum(w * residuals**2) / np.sum(w)

    if return_stats:
        return phi_hat, sigma2_hat, XtWX, XtWy, np.sum(w * residuals**2), np.sum(w)
    else:
        return np.append(phi_hat, sigma2_hat)



def fuse_AR_estimators(stats_list):
    """
    Fuse multiple AR(p) MLE estimators using sufficient statistics.

    Parameters:
    -----------
    stats_list : list of tuples
        Each tuple: (XtWX, XtWy, SSR, total_weight)

    Returns:
    --------
    fused_phi : array
        Combined AR(p) coefficients.
    fused_sigma2 : float
        Combined noise variance estimate.
    """
    S_X_total = None
    S_y_total = None
    SSR_total = 0
    weight_total = 0

    for XtWX, XtWy, SSR, weight in stats_list:
        if S_X_total is None:
            S_X_total = XtWX
            S_y_total = XtWy
        else:
            S_X_total += XtWX
            S_y_total += XtWy
        SSR_total += SSR
        weight_total += weight

    phi_fused = np.linalg.solve(S_X_total, S_y_total)
    sigma2_fused = SSR_total / weight_total

    return np.append(phi_fused, sigma2_fused)

def likelihoods(data, params_matrix, p=3, w=None):
    """
    Compute the log-likelihoods of an AR(p) process for multiple parameter sets.

    Parameters:
        params_matrix : array_like, shape (n_params, p+1)
            Each row contains [phi1, ..., phip, sigma] for one simulation
        data : array_like, shape (n,)
            Time series data as a 1D NumPy array
        p : int
            Order of the autoregressive process

    Returns:
        log_likelihoods : ndarray, shape (n_params,)
            Array of log-likelihoods for each parameter set
    """
    data = np.asarray(data)
    n = len(data)
    if n <= p:
        return np.full(len(params_matrix), -np.inf)

    # Lag matrix (X) and target vector (y)
    X = np.column_stack([data[p - i - 1 : n - i - 1] for i in range(p)])
    y = data[p:]

    params_matrix = np.atleast_2d(params_matrix)
    log_likelihoods = np.empty(params_matrix.shape[0])

    for i, params in enumerate(params_matrix):
        log_likelihoods[i] = Likelihood(params, data, p=p, w=w)
    return np.array(log_likelihoods).reshape(-1, 1).T


#Simplifying numpy notation
def plus(a,b,c=0,d=0,e=0,h=0,i=0,j=0,k=0, l=0):
    sum_of_all = np.add(a,np.add(b,np.add(c,np.add(d,np.add(e,np.add(h,np.add(i,np.add(j,np.add(k,l)))))))))
    return sum_of_all

def neg(a):
    neg_a = np.multiply(a,-1)
    return neg_a

def product(a,b,c=1,d=1,e=1,h=1,i=1,j=1):
    product_of_all = np.multiply(a,np.multiply(b,np.multiply(c,np.multiply(d,np.multiply(e,np.multiply(h,np.multiply(i,j)))))))
    return product_of_all

#Function for Confidence Interval
def norm_CI(data, alpha=0.95):
    n = len(data)
    m, se = np.mean(data, axis=1), np.std(data,axis=1)
    h = se * stats.norm.ppf((1+alpha)/2)
    return m,m-h, m+h

# %%
repeat_sim = 10
dataset_number = 1
vec = np.repeat(dataset_number, repeat_sim)

count = 0
for h in vec:
    print(f"Running simulation: {h}")
    count += 1
    DT_N = simulate(n_total, coeffs, change_points)
    Data_N = np.array(DT_N.N)
    AR_lags = len(coeffs[0])

    if count == 1:
        plt.figure()
        plt.plot(DT_N.Date, DT_N.N, color='k')
        plt.tick_params(axis="x", labelsize=20, labelrotation=45)
        plt.tick_params(axis="y", labelsize=20)
        lengths_name = str(n_total)
        coeffs_name = "initial"
        filename = f"{dataset_number}_AR3_{lengths_name}_{coeffs_name}_data.png"

    start = timeit.default_timer()
    io = Data_N.shape[0]
    c = 1.35
    n_0 = 200
    I_0 = list(Data_N[max(0, io - n_0):io])
    alpha = 0.95
    num_sim = 10

    n_k_minus1 = n_0
    I_k_minus1 = I_0

    windows, MLEs, scaled_windows = [], [], []
    tests = 0

    for l in range(0, Data_N.shape[0]):
        try:
            start_step = timeit.default_timer()
            io = Data_N.shape[0] - l
            
            #arithmetic
            K = int(io/n_0)
            
            #geometric
            # K = max(0, math.ceil((math.log(io) - math.log(n_0)) / math.log(c)))
            
            I_0 = list(Data_N[max(0, io - n_0):io])
            I_k_minus1 = I_0
    
            for k in range(1, K + 1):
                try:
                    #arithmetic
                    n_k = (k+1)*n_0
                    n_k_plus1 = (k+2)*n_0
        
                    #geometric
                    # n_k = int(n_0 * c**k)
                    # n_k_plus1 = int(n_0 * c**(k + 1))
        
                    I_k = list(Data_N[max(0, io - n_k):io])
                    # print(f"I_k Size: {len(I_k)}")
                    I_k_plus1 = list(Data_N[max(0, io - n_k_plus1):io])
                    MLE_I_k_plus1 = MLE_estimator(I_k_plus1, AR_lags)
        
                    J = list(range(max(AR_lags + 1, io - n_k), io - n_k_minus1))
                    T, T_b = [], []
        
                    for i in J:
                       #New intervals and their estimators
                        A_k = np.array(Data_N[max(0,io-n_k_plus1):(i+1)])
                        B_k = np.array(Data_N[i+1:io])
                        MLE_A = MLE_estimator(A_k)
                        MLE_B = MLE_estimator(B_k)
        
                        # test statistics for this breakpoint and adding it to the list
                        T_I_k = Likelihood(MLE_A, A_k) + Likelihood(MLE_B, B_k) - Likelihood(MLE_I_k_plus1, I_k_plus1)
                        T.append(T_I_k)
        
                        ## Bootstrap procedure
                        #  Getting lengths of intervals
                        len_A = len(A_k) #length of A_k
                        len_B = len(B_k) #length of B_k
        
                        #generating weights and
                        #calculating estimators for the bootstrap intervals
                        weights_A = weights_matrix(num_sim,len_A)[:, 0]
                        MLEs_A_b= MLE_estimator(A_k, p=AR_lags, w=weights_A)
        
                        log_ratio_A= likelihoods(A_k, MLEs_A_b, w=weights_A)
                        log_ratio_A = log_ratio_A
        
        
                        weights_B = weights_matrix(num_sim, len_B)[:, 0]
                        MLEs_B_b= MLE_estimator(B_k, p=AR_lags, w=weights_B)
        
                        loglikes_B= likelihoods(B_k, MLEs_B_b, w=weights_B)
        
                        log_ratio_B = loglikes_B
        
                        phi_A, sigma_A, SX_A, Sy_A, SSR_A, W_A = MLE_estimator(A_k, p=AR_lags, w=weights_A, return_stats=True)
                        phi_B, sigma_B, SX_B, Sy_B, SSR_B, W_B = MLE_estimator(B_k, p=AR_lags, w=weights_B, return_stats=True)
                        MLE_p = fuse_AR_estimators([
                            (SX_A, Sy_A, SSR_A, W_A),
                            (SX_B, Sy_B, SSR_B, W_B)
                        ])
        
                        
                        loglikes_p1= likelihoods(A_k, MLE_p, w=weights_A)
                        log_ratio_p1 = loglikes_p1
        
                        loglikes_p2= likelihoods(B_k, plus(MLE_p,MLE_A,MLE_B), w=weights_B)
                        log_ratio_p2 = loglikes_p2
        
                        sup_term = log_ratio_p1 +log_ratio_p2
                        #Test statistic for bootstrap for this breakpoint
                        T_I_k_b = np.subtract(np.add(log_ratio_A,log_ratio_B),sup_term)
                        T_b.append(T_I_k_b)
                        tests= tests+1
        
                    if len(J) > AR_lags + 1:
                        BS_dist = np.max(T_b, axis=0)
                        # print(BS_dist)
                        if len(BS_dist) > 0 and np.all(BS_dist >= 0):
                            test_value = max(T)
                            q = np.quantile(BS_dist, alpha)
                            critical_value = math.sqrt(2 * max(q, 0))
                            print(f"[DEBUG] test_value={test_value}, critical_value={critical_value}, len(BS_dist)={len(BS_dist)}, len(I_k)={len(I_k)}")
                        else:
                            test_value = 0
                            critical_value = 1
                    else:
                        test_value = 0
                        critical_value = 1
                    
                    if test_value > critical_value:
                        print(f"Found break for point {l} window size: {len(I_k)}")
                        break
                    else:
                        continue
                except ValueError as e:
                    print(e)
                    print(f"[DEBUG] Interval too small for AR({AR_lags}) process")
                    continue
    
            if K == 0:
                I_k = I_0
            windows.append(len(I_k))
            MLE_I_k = MLE_estimator(I_k, AR_lags)
            MLEs.append(MLE_I_k)
            scaled_windows.append(len(I_k)  / io)
            stop_step = timeit.default_timer()
            print(f"Step number: {l}, time per step: {stop_step - start_step:.2f}, window size: {len(I_k)}")
        except ValueError as e:
            print(e)
            print(f"[DEBUG] Interval too small for AR({AR_lags}) process")
            continue

    stop = timeit.default_timer()
    print(f"Simulation number: {count}\nTime: {stop - start:.2f} seconds\nTotal tests: {tests}")

    MLEs.reverse()
    windows.reverse()
    scaled_windows.reverse()
    MLEs = np.array(MLEs)

    DT_N['windows_' + str(count)] = pd.Series(windows)
    DT_N['scaled_windows_' + str(count)] = pd.Series(scaled_windows)
    DT_N['MLEs_B_1' + str(count)] = pd.Series(MLEs[:, 0])
    DT_N['MLEs_B_2' + str(count)] = pd.Series(MLEs[:, 1])
    DT_N['MLEs_B_3' + str(count)] = pd.Series(MLEs[:, 2])
    DT_N['MLEs_sigma_2' + str(count)] = pd.Series(MLEs[:, 3])

    filename = f"Arithmetic/{n_0}/{count}_{dataset_number}_AR3_{lengths_name}_{coeffs_name}_data.csv"
    DT_N.to_csv(filename, index=False)
# Out:
# Running simulation: 1
# [DEBUG] test_value=181.83493207185825, critical_value=34.87246554106055, len(BS_dist)=1, len(I_k)=400
# Found break for point 0 window size: 400
# Step number: 0, time per step: 1.16, window size: 400
# [DEBUG] test_value=182.0805262757351, critical_value=34.520116650266054, len(BS_dist)=1, len(I_k)=400
# Found break for point 1 window size: 400
# Step number: 1, time per step: 1.16, window size: 400
# [DEBUG] test_value=186.41588341002034, critical_value=36.09268004489467, len(BS_dist)=1, len(I_k)=400
# Found break for point 2 window size: 400
# Step number: 2, time per step: 1.16, window size: 400
# [DEBUG] test_value=189.5939365189355, critical_value=36.55743736711763, len(BS_dist)=1, len(I_k)=400
# Found break for point 3 window size: 400
# Step number: 3, time per step: 1.12, window size: 400
# [DEBUG] test_value=191.60217022087124, critical_value=35.098957682005654, len(BS_dist)=1, len(I_k)=400
# Found break for point 4 window size: 400
# Step number: 4, time per step: 1.10, window size: 400
# [DEBUG] test_value=192.54103908408626, critical_value=34.87792831087436, len(BS_dist)=1, len(I_k)=400
# Found break for point 5 window size: 400
# Step number: 5, time per step: 1.08, window size: 400
# [DEBUG] test_value=194.64906931667656, critical_value=35.414906466874285, len(BS_dist)=1, len(I_k)=400
# Found break for point 6 window size: 400
# Step number: 6, time per step: 1.05, window size: 400
# [DEBUG] test_value=195.90145265442516, critical_value=37.00155680959071, len(BS_dist)=1, len(I_k)=400
# Found break for point 7 window size: 400
# Step number: 7, time per step: 1.02, window size: 400
# [DEBUG] test_value=198.23023682157918, critical_value=35.50264119947875, len(BS_dist)=1, len(I_k)=400
# Found break for point 8 window size: 400
# Step number: 8, time per step: 1.08, window size: 400
# [DEBUG] test_value=199.6587932720288, critical_value=35.81092316030813, len(BS_dist)=1, len(I_k)=400
# Found break for point 9 window size: 400
# Step number: 9, time per step: 1.10, window size: 400
# [DEBUG] test_value=201.09589030255756, critical_value=35.30418188191937, len(BS_dist)=1, len(I_k)=400
# Found break for point 10 window size: 400
# Step number: 10, time per step: 1.14, window size: 400
# [DEBUG] test_value=202.62778207440203, critical_value=35.03177619914078, len(BS_dist)=1, len(I_k)=400
# Found break for point 11 window size: 400
# Step number: 11, time per step: 1.10, window size: 400
# [DEBUG] test_value=205.19406670877743, critical_value=36.27172590249117, len(BS_dist)=1, len(I_k)=400
# Found break for point 12 window size: 400
# Step number: 12, time per step: 1.01, window size: 400
# [DEBUG] test_value=205.37324579716687, critical_value=35.39898433311974, len(BS_dist)=1, len(I_k)=400
# Found break for point 13 window size: 400
# Step number: 13, time per step: 1.04, window size: 400
# [DEBUG] test_value=205.73575097551543, critical_value=34.591093344312796, len(BS_dist)=1, len(I_k)=400
# Found break for point 14 window size: 400
# Step number: 14, time per step: 1.04, window size: 400
# [DEBUG] test_value=207.18997789195282, critical_value=35.498551366845774, len(BS_dist)=1, len(I_k)=400
# Found break for point 15 window size: 400
# Step number: 15, time per step: 1.02, window size: 400
# [DEBUG] test_value=206.9566015984758, critical_value=36.13651619932819, len(BS_dist)=1, len(I_k)=400
# Found break for point 16 window size: 400
# Step number: 16, time per step: 1.04, window size: 400
# [DEBUG] test_value=207.31889898064856, critical_value=36.389422450327125, len(BS_dist)=1, len(I_k)=400
# Found break for point 17 window size: 400
# Step number: 17, time per step: 1.05, window size: 400
# [DEBUG] test_value=210.04377473881243, critical_value=35.70998427450145, len(BS_dist)=1, len(I_k)=400
# Found break for point 18 window size: 400
# Step number: 18, time per step: 1.01, window size: 400
# [DEBUG] test_value=208.9857258571725, critical_value=34.659149057285504, len(BS_dist)=1, len(I_k)=400
# Found break for point 19 window size: 400
# Step number: 19, time per step: 1.06, window size: 400
# [DEBUG] test_value=209.04060177799988, critical_value=35.7479224612957, len(BS_dist)=1, len(I_k)=400
# Found break for point 20 window size: 400
# Step number: 20, time per step: 1.03, window size: 400
# [DEBUG] test_value=210.57701950187925, critical_value=35.98680482505304, len(BS_dist)=1, len(I_k)=400
# Found break for point 21 window size: 400
# Step number: 21, time per step: 1.07, window size: 400
# [DEBUG] test_value=211.8500341599389, critical_value=35.73618103372131, len(BS_dist)=1, len(I_k)=400
# Found break for point 22 window size: 400
# Step number: 22, time per step: 0.95, window size: 400
# [DEBUG] test_value=211.97602637825162, critical_value=35.921566978363536, len(BS_dist)=1, len(I_k)=400
# Found break for point 23 window size: 400
# Step number: 23, time per step: 1.10, window size: 400
# [DEBUG] test_value=217.4600199197822, critical_value=36.20083952612884, len(BS_dist)=1, len(I_k)=400
# Found break for point 24 window size: 400
# Step number: 24, time per step: 1.14, window size: 400
# [DEBUG] test_value=216.9734324214437, critical_value=35.85650987598853, len(BS_dist)=1, len(I_k)=400
# Found break for point 25 window size: 400
# Step number: 25, time per step: 0.95, window size: 400
# [DEBUG] test_value=216.31790660082447, critical_value=35.963242563487405, len(BS_dist)=1, len(I_k)=400
# Found break for point 26 window size: 400
# Step number: 26, time per step: 0.96, window size: 400
# [DEBUG] test_value=216.28268254656734, critical_value=36.744873590337924, len(BS_dist)=1, len(I_k)=400
# Found break for point 27 window size: 400
# Step number: 27, time per step: 1.00, window size: 400
# [DEBUG] test_value=216.95720479693296, critical_value=36.71004810415578, len(BS_dist)=1, len(I_k)=400
# Found break for point 28 window size: 400
# Step number: 28, time per step: 0.99, window size: 400
# [DEBUG] test_value=216.2367418083918, critical_value=35.78059053070669, len(BS_dist)=1, len(I_k)=400
# Found break for point 29 window size: 400
# Step number: 29, time per step: 1.03, window size: 400
# [DEBUG] test_value=217.5134510014941, critical_value=36.538261092622044, len(BS_dist)=1, len(I_k)=400
# Found break for point 30 window size: 400
# Step number: 30, time per step: 0.97, window size: 400
# [DEBUG] test_value=217.47371298304643, critical_value=35.986424923228356, len(BS_dist)=1, len(I_k)=400
# Found break for point 31 window size: 400
# Step number: 31, time per step: 1.03, window size: 400
# [DEBUG] test_value=217.31069810639303, critical_value=36.110476371041386, len(BS_dist)=1, len(I_k)=400
# Found break for point 32 window size: 400
# Step number: 32, time per step: 1.04, window size: 400
# [DEBUG] test_value=216.72467517093276, critical_value=36.84473886646372, len(BS_dist)=1, len(I_k)=400
# Found break for point 33 window size: 400
# Step number: 33, time per step: 1.03, window size: 400
# [DEBUG] test_value=216.56563052848037, critical_value=36.75939882238783, len(BS_dist)=1, len(I_k)=400
# Found break for point 34 window size: 400
# Step number: 34, time per step: 0.96, window size: 400
# [DEBUG] test_value=216.15267264034458, critical_value=37.48854238937833, len(BS_dist)=1, len(I_k)=400
# Found break for point 35 window size: 400
# Step number: 35, time per step: 0.98, window size: 400
# [DEBUG] test_value=217.79006557631124, critical_value=37.93720429918795, len(BS_dist)=1, len(I_k)=400
# Found break for point 36 window size: 400
# Step number: 36, time per step: 1.04, window size: 400
# [DEBUG] test_value=217.24384237848574, critical_value=36.41012495132633, len(BS_dist)=1, len(I_k)=400
# Found break for point 37 window size: 400
# Step number: 37, time per step: 1.01, window size: 400
# [DEBUG] test_value=216.6988309176229, critical_value=36.910284761327155, len(BS_dist)=1, len(I_k)=400
# Found break for point 38 window size: 400
# Step number: 38, time per step: 1.05, window size: 400
# [DEBUG] test_value=216.73312616321027, critical_value=37.11487266104875, len(BS_dist)=1, len(I_k)=400
# Found break for point 39 window size: 400
# Step number: 39, time per step: 1.08, window size: 400
# [DEBUG] test_value=218.8482766887622, critical_value=35.73663759176156, len(BS_dist)=1, len(I_k)=400
# Found break for point 40 window size: 400
# Step number: 40, time per step: 1.06, window size: 400
# [DEBUG] test_value=218.5865307851251, critical_value=35.83892387054973, len(BS_dist)=1, len(I_k)=400
# Found break for point 41 window size: 400
# Step number: 41, time per step: 1.01, window size: 400
# [DEBUG] test_value=219.71094376693225, critical_value=36.46001119522128, len(BS_dist)=1, len(I_k)=400
# Found break for point 42 window size: 400
# Step number: 42, time per step: 0.98, window size: 400
# [DEBUG] test_value=223.13786117174664, critical_value=37.79119582513427, len(BS_dist)=1, len(I_k)=400
# Found break for point 43 window size: 400
# Step number: 43, time per step: 1.03, window size: 400
# [DEBUG] test_value=223.02391545833802, critical_value=36.38332875503164, len(BS_dist)=1, len(I_k)=400
# Found break for point 44 window size: 400
# Step number: 44, time per step: 1.08, window size: 400
# [DEBUG] test_value=223.06820226827494, critical_value=36.73175486838361, len(BS_dist)=1, len(I_k)=400
# Found break for point 45 window size: 400
# Step number: 45, time per step: 1.03, window size: 400
# [DEBUG] test_value=224.55424222771876, critical_value=36.590944536271834, len(BS_dist)=1, len(I_k)=400
# Found break for point 46 window size: 400
# Step number: 46, time per step: 1.00, window size: 400
# [DEBUG] test_value=224.49498656081118, critical_value=36.689470640086505, len(BS_dist)=1, len(I_k)=400
# Found break for point 47 window size: 400
# Step number: 47, time per step: 0.94, window size: 400
# [DEBUG] test_value=224.7234870144058, critical_value=36.64615784880823, len(BS_dist)=1, len(I_k)=400
# Found break for point 48 window size: 400
# Step number: 48, time per step: 0.98, window size: 400
# [DEBUG] test_value=224.07919499410752, critical_value=36.47534157753959, len(BS_dist)=1, len(I_k)=400
# Found break for point 49 window size: 400
# Step number: 49, time per step: 0.97, window size: 400
# [DEBUG] test_value=223.85105252257654, critical_value=37.728636835962426, len(BS_dist)=1, len(I_k)=400
# Found break for point 50 window size: 400
# Step number: 50, time per step: 1.06, window size: 400
# [DEBUG] test_value=223.98988560351847, critical_value=37.490409474646995, len(BS_dist)=1, len(I_k)=400
# Found break for point 51 window size: 400
# Step number: 51, time per step: 1.01, window size: 400
# [DEBUG] test_value=224.40750482941326, critical_value=36.450956019490086, len(BS_dist)=1, len(I_k)=400
# Found break for point 52 window size: 400
# Step number: 52, time per step: 1.14, window size: 400
# [DEBUG] test_value=225.4406416672009, critical_value=37.41013252761666, len(BS_dist)=1, len(I_k)=400
# Found break for point 53 window size: 400
# Step number: 53, time per step: 1.06, window size: 400
# [DEBUG] test_value=224.88366068165942, critical_value=36.17137309894901, len(BS_dist)=1, len(I_k)=400
# Found break for point 54 window size: 400
# Step number: 54, time per step: 1.17, window size: 400
# [DEBUG] test_value=224.3358163589387, critical_value=36.11715107713684, len(BS_dist)=1, len(I_k)=400
# Found break for point 55 window size: 400
# Step number: 55, time per step: 1.13, window size: 400
# [DEBUG] test_value=224.40093159995365, critical_value=36.73537842449609, len(BS_dist)=1, len(I_k)=400
# Found break for point 56 window size: 400
# Step number: 56, time per step: 0.96, window size: 400
# [DEBUG] test_value=224.76071241816385, critical_value=35.95901588213812, len(BS_dist)=1, len(I_k)=400
# Found break for point 57 window size: 400
# Step number: 57, time per step: 1.00, window size: 400
# [DEBUG] test_value=225.60814735902522, critical_value=39.26603191188814, len(BS_dist)=1, len(I_k)=400
# Found break for point 58 window size: 400
# Step number: 58, time per step: 0.98, window size: 400
# [DEBUG] test_value=226.34419549039876, critical_value=36.56787410319277, len(BS_dist)=1, len(I_k)=400
# Found break for point 59 window size: 400
# Step number: 59, time per step: 1.06, window size: 400
# [DEBUG] test_value=230.10501403658213, critical_value=38.54755532098276, len(BS_dist)=1, len(I_k)=400
# Found break for point 60 window size: 400
# Step number: 60, time per step: 1.01, window size: 400
# [DEBUG] test_value=231.59282573448775, critical_value=38.02752657219839, len(BS_dist)=1, len(I_k)=400
# Found break for point 61 window size: 400
# Step number: 61, time per step: 1.02, window size: 400
# [DEBUG] test_value=231.8655485998903, critical_value=37.033872046511796, len(BS_dist)=1, len(I_k)=400
# Found break for point 62 window size: 400
# Step number: 62, time per step: 1.02, window size: 400
# [DEBUG] test_value=232.10468997572195, critical_value=37.57228785708067, len(BS_dist)=1, len(I_k)=400
# Found break for point 63 window size: 400
# Step number: 63, time per step: 1.02, window size: 400
# [DEBUG] test_value=233.93191622522977, critical_value=38.014468647405224, len(BS_dist)=1, len(I_k)=400
# Found break for point 64 window size: 400
# Step number: 64, time per step: 0.99, window size: 400
# [DEBUG] test_value=233.60128844991948, critical_value=37.1709190706973, len(BS_dist)=1, len(I_k)=400
# Found break for point 65 window size: 400
# Step number: 65, time per step: 1.01, window size: 400
# [DEBUG] test_value=236.01455979619573, critical_value=38.39994226675347, len(BS_dist)=1, len(I_k)=400
# Found break for point 66 window size: 400
# Step number: 66, time per step: 1.04, window size: 400
# [DEBUG] test_value=236.05000052379523, critical_value=37.19066346917066, len(BS_dist)=1, len(I_k)=400
# Found break for point 67 window size: 400
# Step number: 67, time per step: 0.98, window size: 400
# [DEBUG] test_value=235.93038108138126, critical_value=39.84013766308171, len(BS_dist)=1, len(I_k)=400
# Found break for point 68 window size: 400
# Step number: 68, time per step: 1.06, window size: 400
# [DEBUG] test_value=236.03251542095654, critical_value=38.86987424855999, len(BS_dist)=1, len(I_k)=400
# Found break for point 69 window size: 400
# Step number: 69, time per step: 0.99, window size: 400
# [DEBUG] test_value=236.8395753904432, critical_value=38.897207247129415, len(BS_dist)=1, len(I_k)=400
# Found break for point 70 window size: 400
# Step number: 70, time per step: 0.99, window size: 400
# [DEBUG] test_value=238.16318272250453, critical_value=38.43869685177571, len(BS_dist)=1, len(I_k)=400
# Found break for point 71 window size: 400
# Step number: 71, time per step: 0.94, window size: 400
# [DEBUG] test_value=239.79046721448253, critical_value=38.98080033258695, len(BS_dist)=1, len(I_k)=400
# Found break for point 72 window size: 400
# Step number: 72, time per step: 0.96, window size: 400
# [DEBUG] test_value=239.77855233335004, critical_value=37.09676739732865, len(BS_dist)=1, len(I_k)=400
# Found break for point 73 window size: 400
# Step number: 73, time per step: 1.00, window size: 400
# [DEBUG] test_value=243.45026726695903, critical_value=39.68507598064865, len(BS_dist)=1, len(I_k)=400
# Found break for point 74 window size: 400
# Step number: 74, time per step: 1.08, window size: 400
# [DEBUG] test_value=242.97433217907383, critical_value=38.99136812633088, len(BS_dist)=1, len(I_k)=400
# Found break for point 75 window size: 400
# Step number: 75, time per step: 0.98, window size: 400
# [DEBUG] test_value=243.05344495291126, critical_value=39.05047402916007, len(BS_dist)=1, len(I_k)=400
# Found break for point 76 window size: 400
# Step number: 76, time per step: 0.97, window size: 400
# [DEBUG] test_value=242.46671569015302, critical_value=39.80372106089278, len(BS_dist)=1, len(I_k)=400
# Found break for point 77 window size: 400
# Step number: 77, time per step: 1.01, window size: 400
# [DEBUG] test_value=242.3736141703631, critical_value=40.01402786952628, len(BS_dist)=1, len(I_k)=400
# Found break for point 78 window size: 400
# Step number: 78, time per step: 1.00, window size: 400
# [DEBUG] test_value=245.8913326727262, critical_value=38.25455664557565, len(BS_dist)=1, len(I_k)=400
# Found break for point 79 window size: 400
# Step number: 79, time per step: 1.03, window size: 400
# [DEBUG] test_value=250.72331006062632, critical_value=40.00609765569254, len(BS_dist)=1, len(I_k)=400
# Found break for point 80 window size: 400
# Step number: 80, time per step: 1.07, window size: 400
# [DEBUG] test_value=249.6980407085464, critical_value=37.8213153178702, len(BS_dist)=1, len(I_k)=400
# Found break for point 81 window size: 400
# Step number: 81, time per step: 1.07, window size: 400
# [DEBUG] test_value=254.360096014668, critical_value=39.20762323086307, len(BS_dist)=1, len(I_k)=400
# Found break for point 82 window size: 400
# Step number: 82, time per step: 1.04, window size: 400
# [DEBUG] test_value=255.84026999652394, critical_value=39.55368009327823, len(BS_dist)=1, len(I_k)=400
# Found break for point 83 window size: 400
# Step number: 83, time per step: 1.03, window size: 400
# [DEBUG] test_value=255.23941774077537, critical_value=38.10295054031701, len(BS_dist)=1, len(I_k)=400
# Found break for point 84 window size: 400
# Step number: 84, time per step: 1.01, window size: 400
# [DEBUG] test_value=255.8525804421455, critical_value=38.02471611566552, len(BS_dist)=1, len(I_k)=400
# Found break for point 85 window size: 400
# Step number: 85, time per step: 1.01, window size: 400
# [DEBUG] test_value=252.66989499025658, critical_value=38.731312558925744, len(BS_dist)=1, len(I_k)=400
# Found break for point 86 window size: 400
# Step number: 86, time per step: 1.03, window size: 400
# [DEBUG] test_value=252.71757002746938, critical_value=37.73504113975566, len(BS_dist)=1, len(I_k)=400
# Found break for point 87 window size: 400
# Step number: 87, time per step: 0.99, window size: 400
# [DEBUG] test_value=252.04110272231048, critical_value=39.253967694443965, len(BS_dist)=1, len(I_k)=400
# Found break for point 88 window size: 400
# Step number: 88, time per step: 1.02, window size: 400
# [DEBUG] test_value=250.5389152892069, critical_value=37.94777716498869, len(BS_dist)=1, len(I_k)=400
# Found break for point 89 window size: 400
# Step number: 89, time per step: 0.99, window size: 400
# [DEBUG] test_value=252.65603837840672, critical_value=38.484695221290444, len(BS_dist)=1, len(I_k)=400
# Found break for point 90 window size: 400
# Step number: 90, time per step: 1.03, window size: 400
# [DEBUG] test_value=252.98574374831765, critical_value=38.359626514985464, len(BS_dist)=1, len(I_k)=400
# Found break for point 91 window size: 400
# Step number: 91, time per step: 1.00, window size: 400
# [DEBUG] test_value=254.71332650186264, critical_value=41.42092049498715, len(BS_dist)=1, len(I_k)=400
# Found break for point 92 window size: 400
# Step number: 92, time per step: 1.05, window size: 400
# [DEBUG] test_value=254.81787464903766, critical_value=39.665128837521735, len(BS_dist)=1, len(I_k)=400
# Found break for point 93 window size: 400
# Step number: 93, time per step: 1.03, window size: 400
# [DEBUG] test_value=254.7169579506931, critical_value=39.44442836496969, len(BS_dist)=1, len(I_k)=400
# Found break for point 94 window size: 400
# Step number: 94, time per step: 1.01, window size: 400
# [DEBUG] test_value=254.50494704969174, critical_value=38.216385253204855, len(BS_dist)=1, len(I_k)=400
# Found break for point 95 window size: 400
# Step number: 95, time per step: 1.19, window size: 400
# [DEBUG] test_value=254.82043572310067, critical_value=39.542211496505644, len(BS_dist)=1, len(I_k)=400
# Found break for point 96 window size: 400
# Step number: 96, time per step: 1.06, window size: 400
# [DEBUG] test_value=254.01520040540117, critical_value=38.36027553277307, len(BS_dist)=1, len(I_k)=400
# Found break for point 97 window size: 400
# Step number: 97, time per step: 0.97, window size: 400
# [DEBUG] test_value=253.64685533256466, critical_value=38.65382999246122, len(BS_dist)=1, len(I_k)=400
# Found break for point 98 window size: 400
# Step number: 98, time per step: 1.04, window size: 400
# [DEBUG] test_value=253.19363764664763, critical_value=38.132750858364666, len(BS_dist)=1, len(I_k)=400
# Found break for point 99 window size: 400
# Step number: 99, time per step: 0.96, window size: 400
# [DEBUG] test_value=252.87326050165018, critical_value=37.71776507792376, len(BS_dist)=1, len(I_k)=400
# Found break for point 100 window size: 400
# Step number: 100, time per step: 1.04, window size: 400
# [DEBUG] test_value=252.8815907718124, critical_value=40.39498324136863, len(BS_dist)=1, len(I_k)=400
# Found break for point 101 window size: 400
# Step number: 101, time per step: 1.10, window size: 400
# [DEBUG] test_value=253.08478519073674, critical_value=39.048616597039654, len(BS_dist)=1, len(I_k)=400
# Found break for point 102 window size: 400
# Step number: 102, time per step: 1.06, window size: 400
# [DEBUG] test_value=252.04961592595805, critical_value=37.70535580862897, len(BS_dist)=1, len(I_k)=400
# Found break for point 103 window size: 400
# Step number: 103, time per step: 0.99, window size: 400
# [DEBUG] test_value=251.16590684121752, critical_value=38.47565573274874, len(BS_dist)=1, len(I_k)=400
# Found break for point 104 window size: 400
# Step number: 104, time per step: 0.96, window size: 400
# [DEBUG] test_value=250.7680062889816, critical_value=40.90238515099708, len(BS_dist)=1, len(I_k)=400
# Found break for point 105 window size: 400
# Step number: 105, time per step: 1.03, window size: 400
# [DEBUG] test_value=250.15919230719612, critical_value=39.02740033372397, len(BS_dist)=1, len(I_k)=400
# Found break for point 106 window size: 400
# Step number: 106, time per step: 0.97, window size: 400
# [DEBUG] test_value=250.2076590055226, critical_value=38.94136899547012, len(BS_dist)=1, len(I_k)=400
# Found break for point 107 window size: 400
# Step number: 107, time per step: 1.10, window size: 400
# [DEBUG] test_value=250.1885454148578, critical_value=38.699939981852765, len(BS_dist)=1, len(I_k)=400
# Found break for point 108 window size: 400
# Step number: 108, time per step: 1.01, window size: 400
# [DEBUG] test_value=250.22574797631898, critical_value=38.233805327536395, len(BS_dist)=1, len(I_k)=400
# Found break for point 109 window size: 400
# Step number: 109, time per step: 0.95, window size: 400
# [DEBUG] test_value=250.47850833080122, critical_value=38.74071096784812, len(BS_dist)=1, len(I_k)=400
# Found break for point 110 window size: 400
# Step number: 110, time per step: 0.97, window size: 400
# [DEBUG] test_value=250.3399959332903, critical_value=39.270409300944934, len(BS_dist)=1, len(I_k)=400
# Found break for point 111 window size: 400
# Step number: 111, time per step: 0.96, window size: 400
# [DEBUG] test_value=250.01793412260895, critical_value=39.04097051770212, len(BS_dist)=1, len(I_k)=400
# Found break for point 112 window size: 400
# Step number: 112, time per step: 1.01, window size: 400
# [DEBUG] test_value=250.1810758520969, critical_value=40.31979132433965, len(BS_dist)=1, len(I_k)=400
# Found break for point 113 window size: 400
# Step number: 113, time per step: 1.07, window size: 400
# [DEBUG] test_value=250.18592046101003, critical_value=38.316612541263495, len(BS_dist)=1, len(I_k)=400
# Found break for point 114 window size: 400
# Step number: 114, time per step: 1.07, window size: 400
# [DEBUG] test_value=250.1149567234222, critical_value=39.259887973772734, len(BS_dist)=1, len(I_k)=400
# Found break for point 115 window size: 400
# Step number: 115, time per step: 0.97, window size: 400
# [DEBUG] test_value=250.35088629457357, critical_value=38.97964565811651, len(BS_dist)=1, len(I_k)=400
# Found break for point 116 window size: 400
# Step number: 116, time per step: 0.99, window size: 400
# [DEBUG] test_value=250.1456244430268, critical_value=40.477341408247874, len(BS_dist)=1, len(I_k)=400
# Found break for point 117 window size: 400
# Step number: 117, time per step: 1.13, window size: 400
# [DEBUG] test_value=250.53237671382442, critical_value=39.67370275769591, len(BS_dist)=1, len(I_k)=400
# Found break for point 118 window size: 400
# Step number: 118, time per step: 0.96, window size: 400
# [DEBUG] test_value=250.69992109531745, critical_value=39.093516980895565, len(BS_dist)=1, len(I_k)=400
# Found break for point 119 window size: 400
# Step number: 119, time per step: 1.06, window size: 400
# [DEBUG] test_value=250.26950426200187, critical_value=38.65102251425854, len(BS_dist)=1, len(I_k)=400
# Found break for point 120 window size: 400
# Step number: 120, time per step: 1.00, window size: 400
# [DEBUG] test_value=250.9732872458386, critical_value=39.64049683794546, len(BS_dist)=1, len(I_k)=400
# Found break for point 121 window size: 400
# Step number: 121, time per step: 0.99, window size: 400
# [DEBUG] test_value=250.81466527932923, critical_value=39.135983509394784, len(BS_dist)=1, len(I_k)=400
# Found break for point 122 window size: 400
# Step number: 122, time per step: 1.05, window size: 400
# [DEBUG] test_value=249.03802447573412, critical_value=40.31700862534773, len(BS_dist)=1, len(I_k)=400
# Found break for point 123 window size: 400
# Step number: 123, time per step: 1.05, window size: 400
# [DEBUG] test_value=250.50448468639377, critical_value=38.468164463553904, len(BS_dist)=1, len(I_k)=400
# Found break for point 124 window size: 400
# Step number: 124, time per step: 1.08, window size: 400
# [DEBUG] test_value=250.08360967588237, critical_value=39.46610807518697, len(BS_dist)=1, len(I_k)=400
# Found break for point 125 window size: 400
# Step number: 125, time per step: 1.03, window size: 400
# [DEBUG] test_value=249.7419171242202, critical_value=37.930471231038645, len(BS_dist)=1, len(I_k)=400
# Found break for point 126 window size: 400
# Step number: 126, time per step: 1.14, window size: 400
# [DEBUG] test_value=250.24650892948068, critical_value=38.72549018596131, len(BS_dist)=1, len(I_k)=400
# Found break for point 127 window size: 400
# Step number: 127, time per step: 1.22, window size: 400
# [DEBUG] test_value=250.0620920151989, critical_value=37.835464534327436, len(BS_dist)=1, len(I_k)=400
# Found break for point 128 window size: 400
# Step number: 128, time per step: 1.19, window size: 400
# [DEBUG] test_value=249.3812083465025, critical_value=38.7172988460971, len(BS_dist)=1, len(I_k)=400
# Found break for point 129 window size: 400
# Step number: 129, time per step: 1.03, window size: 400
# [DEBUG] test_value=249.54964269523248, critical_value=38.70045636887638, len(BS_dist)=1, len(I_k)=400
# Found break for point 130 window size: 400
# Step number: 130, time per step: 1.01, window size: 400
# [DEBUG] test_value=248.67521424811082, critical_value=38.216824426115274, len(BS_dist)=1, len(I_k)=400
# Found break for point 131 window size: 400
# Step number: 131, time per step: 0.98, window size: 400
# [DEBUG] test_value=248.23807833555566, critical_value=38.19306593893867, len(BS_dist)=1, len(I_k)=400
# Found break for point 132 window size: 400
# Step number: 132, time per step: 1.03, window size: 400
# [DEBUG] test_value=248.05808752410212, critical_value=37.85443993538067, len(BS_dist)=1, len(I_k)=400
# Found break for point 133 window size: 400
# Step number: 133, time per step: 1.05, window size: 400
# [DEBUG] test_value=248.09114821996377, critical_value=37.19530846605403, len(BS_dist)=1, len(I_k)=400
# Found break for point 134 window size: 400
# Step number: 134, time per step: 0.98, window size: 400
# [DEBUG] test_value=247.9802781935805, critical_value=38.763651076247854, len(BS_dist)=1, len(I_k)=400
# Found break for point 135 window size: 400
# Step number: 135, time per step: 1.04, window size: 400
# [DEBUG] test_value=247.19939728399038, critical_value=38.05596162896089, len(BS_dist)=1, len(I_k)=400
# Found break for point 136 window size: 400
# Step number: 136, time per step: 0.99, window size: 400
# [DEBUG] test_value=247.60748307706308, critical_value=38.28620249412801, len(BS_dist)=1, len(I_k)=400
# Found break for point 137 window size: 400
# Step number: 137, time per step: 0.95, window size: 400
# [DEBUG] test_value=247.72541176623122, critical_value=38.965598940280415, len(BS_dist)=1, len(I_k)=400
# Found break for point 138 window size: 400
# Step number: 138, time per step: 1.02, window size: 400
# [DEBUG] test_value=247.45040239539924, critical_value=37.65605775561364, len(BS_dist)=1, len(I_k)=400
# Found break for point 139 window size: 400
# Step number: 139, time per step: 0.99, window size: 400
# [DEBUG] test_value=247.49423816675858, critical_value=39.68314265130166, len(BS_dist)=1, len(I_k)=400
# Found break for point 140 window size: 400
# Step number: 140, time per step: 0.96, window size: 400
# [DEBUG] test_value=247.8532314304225, critical_value=37.21630433543461, len(BS_dist)=1, len(I_k)=400
# Found break for point 141 window size: 400
# Step number: 141, time per step: 1.00, window size: 400
# [DEBUG] test_value=247.83612113663116, critical_value=37.039969931414355, len(BS_dist)=1, len(I_k)=400
# Found break for point 142 window size: 400
# Step number: 142, time per step: 0.94, window size: 400
# [DEBUG] test_value=248.3111799353842, critical_value=37.865365267612894, len(BS_dist)=1, len(I_k)=400
# Found break for point 143 window size: 400
# Step number: 143, time per step: 1.05, window size: 400
# [DEBUG] test_value=248.3561270895517, critical_value=39.02458620207085, len(BS_dist)=1, len(I_k)=400
# Found break for point 144 window size: 400
# Step number: 144, time per step: 0.94, window size: 400
# [DEBUG] test_value=248.33692157267, critical_value=38.643519597432984, len(BS_dist)=1, len(I_k)=400
# Found break for point 145 window size: 400
# Step number: 145, time per step: 0.94, window size: 400
# [DEBUG] test_value=247.94871489497336, critical_value=37.30430458140015, len(BS_dist)=1, len(I_k)=400
# Found break for point 146 window size: 400
# Step number: 146, time per step: 1.02, window size: 400
# [DEBUG] test_value=247.7357085946188, critical_value=38.600509995965275, len(BS_dist)=1, len(I_k)=400
# Found break for point 147 window size: 400
# Step number: 147, time per step: 1.02, window size: 400
# [DEBUG] test_value=247.5787568627743, critical_value=36.8273934149436, len(BS_dist)=1, len(I_k)=400
# Found break for point 148 window size: 400
# Step number: 148, time per step: 0.99, window size: 400
# [DEBUG] test_value=247.93939832895353, critical_value=38.14353493377396, len(BS_dist)=1, len(I_k)=400
# Found break for point 149 window size: 400
# Step number: 149, time per step: 0.99, window size: 400
# [DEBUG] test_value=248.16647720763206, critical_value=38.46220444001155, len(BS_dist)=1, len(I_k)=400
# Found break for point 150 window size: 400
# Step number: 150, time per step: 1.06, window size: 400
# [DEBUG] test_value=248.7693413114887, critical_value=38.83487079391117, len(BS_dist)=1, len(I_k)=400
# Found break for point 151 window size: 400
# Step number: 151, time per step: 1.00, window size: 400
# [DEBUG] test_value=248.97377641565743, critical_value=37.86871856809538, len(BS_dist)=1, len(I_k)=400
# Found break for point 152 window size: 400
# Step number: 152, time per step: 1.07, window size: 400
# [DEBUG] test_value=248.8116344615139, critical_value=36.680387883691225, len(BS_dist)=1, len(I_k)=400
# Found break for point 153 window size: 400
# Step number: 153, time per step: 1.03, window size: 400
# [DEBUG] test_value=248.58701780367187, critical_value=36.53854392206169, len(BS_dist)=1, len(I_k)=400
# Found break for point 154 window size: 400
# Step number: 154, time per step: 1.01, window size: 400
# [DEBUG] test_value=248.3662417679409, critical_value=37.52124362896669, len(BS_dist)=1, len(I_k)=400
# Found break for point 155 window size: 400
# Step number: 155, time per step: 0.98, window size: 400
# [DEBUG] test_value=248.42745052461044, critical_value=36.847974550847745, len(BS_dist)=1, len(I_k)=400
# Found break for point 156 window size: 400
# Step number: 156, time per step: 1.04, window size: 400
# [DEBUG] test_value=248.59910935429525, critical_value=38.97462544133402, len(BS_dist)=1, len(I_k)=400
# Found break for point 157 window size: 400
# Step number: 157, time per step: 1.04, window size: 400
# [DEBUG] test_value=248.05944823310756, critical_value=37.570043791710866, len(BS_dist)=1, len(I_k)=400
# Found break for point 158 window size: 400
# Step number: 158, time per step: 1.07, window size: 400
# [DEBUG] test_value=247.6586538716938, critical_value=37.73261769856982, len(BS_dist)=1, len(I_k)=400
# Found break for point 159 window size: 400
# Step number: 159, time per step: 1.12, window size: 400
# [DEBUG] test_value=248.91767014010645, critical_value=37.95903833671731, len(BS_dist)=1, len(I_k)=400
# Found break for point 160 window size: 400
# Step number: 160, time per step: 1.02, window size: 400
# [DEBUG] test_value=249.0070454997225, critical_value=36.32514649635495, len(BS_dist)=1, len(I_k)=400
# Found break for point 161 window size: 400
# Step number: 161, time per step: 0.97, window size: 400
# [DEBUG] test_value=250.01079584516856, critical_value=37.221060185309774, len(BS_dist)=1, len(I_k)=400
# Found break for point 162 window size: 400
# Step number: 162, time per step: 0.98, window size: 400
# [DEBUG] test_value=249.0541569320186, critical_value=38.30187005568677, len(BS_dist)=1, len(I_k)=400
# Found break for point 163 window size: 400
# Step number: 163, time per step: 1.02, window size: 400
# [DEBUG] test_value=250.47718173866224, critical_value=37.56660551576979, len(BS_dist)=1, len(I_k)=400
# Found break for point 164 window size: 400
# Step number: 164, time per step: 1.00, window size: 400
# [DEBUG] test_value=252.61989811385968, critical_value=37.98177120660281, len(BS_dist)=1, len(I_k)=400
# Found break for point 165 window size: 400
# Step number: 165, time per step: 0.94, window size: 400
# [DEBUG] test_value=250.5939839111021, critical_value=37.19228204496222, len(BS_dist)=1, len(I_k)=400
# Found break for point 166 window size: 400
# Step number: 166, time per step: 0.94, window size: 400
# [DEBUG] test_value=250.7014470623842, critical_value=38.02783513328127, len(BS_dist)=1, len(I_k)=400
# Found break for point 167 window size: 400
# Step number: 167, time per step: 1.02, window size: 400
# [DEBUG] test_value=250.03425862094832, critical_value=37.623948531084906, len(BS_dist)=1, len(I_k)=400
# Found break for point 168 window size: 400
# Step number: 168, time per step: 0.99, window size: 400
# [DEBUG] test_value=247.71221894411565, critical_value=36.635342462227186, len(BS_dist)=1, len(I_k)=400
# Found break for point 169 window size: 400
# Step number: 169, time per step: 1.09, window size: 400
# [DEBUG] test_value=246.91459545175917, critical_value=36.48191417147397, len(BS_dist)=1, len(I_k)=400
# Found break for point 170 window size: 400
# Step number: 170, time per step: 1.03, window size: 400
# [DEBUG] test_value=245.8768348511628, critical_value=35.95214646347169, len(BS_dist)=1, len(I_k)=400
# Found break for point 171 window size: 400
# Step number: 171, time per step: 0.95, window size: 400
# [DEBUG] test_value=243.39343483056018, critical_value=36.435054737502455, len(BS_dist)=1, len(I_k)=400
# Found break for point 172 window size: 400
# Step number: 172, time per step: 0.99, window size: 400
# [DEBUG] test_value=243.99548915131356, critical_value=36.76611711136997, len(BS_dist)=1, len(I_k)=400
# Found break for point 173 window size: 400
# Step number: 173, time per step: 1.00, window size: 400
# [DEBUG] test_value=243.9604327152981, critical_value=35.69055486415199, len(BS_dist)=1, len(I_k)=400
# Found break for point 174 window size: 400
# Step number: 174, time per step: 0.96, window size: 400
# [DEBUG] test_value=240.4987022559244, critical_value=36.43184950274796, len(BS_dist)=1, len(I_k)=400
# Found break for point 175 window size: 400
# Step number: 175, time per step: 0.99, window size: 400
# [DEBUG] test_value=237.71982745974753, critical_value=36.52489680148457, len(BS_dist)=1, len(I_k)=400
# Found break for point 176 window size: 400
# Step number: 176, time per step: 0.94, window size: 400
# [DEBUG] test_value=237.0961600736921, critical_value=36.05474107303729, len(BS_dist)=1, len(I_k)=400
# Found break for point 177 window size: 400
# Step number: 177, time per step: 1.02, window size: 400
# [DEBUG] test_value=233.06821445169317, critical_value=36.670181097865274, len(BS_dist)=1, len(I_k)=400
# Found break for point 178 window size: 400
# Step number: 178, time per step: 0.97, window size: 400
# [DEBUG] test_value=233.28773119614584, critical_value=36.052550008157446, len(BS_dist)=1, len(I_k)=400
# Found break for point 179 window size: 400
# Step number: 179, time per step: 1.26, window size: 400
# [DEBUG] test_value=232.8285549599634, critical_value=35.970998367946045, len(BS_dist)=1, len(I_k)=400
# Found break for point 180 window size: 400
# Step number: 180, time per step: 1.09, window size: 400
# [DEBUG] test_value=230.80392816698918, critical_value=35.77361089509112, len(BS_dist)=1, len(I_k)=400
# Found break for point 181 window size: 400
# Step number: 181, time per step: 1.01, window size: 400
# [DEBUG] test_value=231.38232881248598, critical_value=36.21429384569167, len(BS_dist)=1, len(I_k)=400
# Found break for point 182 window size: 400
# Step number: 182, time per step: 0.99, window size: 400
# [DEBUG] test_value=231.43515641443526, critical_value=37.06436657733331, len(BS_dist)=1, len(I_k)=400
# Found break for point 183 window size: 400
# Step number: 183, time per step: 1.07, window size: 400
# [DEBUG] test_value=231.194896419129, critical_value=36.24839063068945, len(BS_dist)=1, len(I_k)=400
# Found break for point 184 window size: 400
# Step number: 184, time per step: 1.00, window size: 400
# [DEBUG] test_value=230.14678074019446, critical_value=36.99724010668472, len(BS_dist)=1, len(I_k)=400
# Found break for point 185 window size: 400
# Step number: 185, time per step: 0.94, window size: 400
# [DEBUG] test_value=228.63806294128472, critical_value=36.584217096949715, len(BS_dist)=1, len(I_k)=400
# Found break for point 186 window size: 400
# Step number: 186, time per step: 0.99, window size: 400
# [DEBUG] test_value=226.9301473783337, critical_value=35.862054083795094, len(BS_dist)=1, len(I_k)=400
# Found break for point 187 window size: 400
# Step number: 187, time per step: 1.04, window size: 400
# [DEBUG] test_value=225.1315266713084, critical_value=35.906276850425336, len(BS_dist)=1, len(I_k)=400
# Found break for point 188 window size: 400
# Step number: 188, time per step: 0.98, window size: 400
# [DEBUG] test_value=225.03547791551432, critical_value=36.03979736619307, len(BS_dist)=1, len(I_k)=400
# Found break for point 189 window size: 400
# Step number: 189, time per step: 0.99, window size: 400
# [DEBUG] test_value=222.22826780459013, critical_value=35.28072422897222, len(BS_dist)=1, len(I_k)=400
# Found break for point 190 window size: 400
# Step number: 190, time per step: 0.95, window size: 400
# [DEBUG] test_value=220.4628847648787, critical_value=36.49746040615999, len(BS_dist)=1, len(I_k)=400
# Found break for point 191 window size: 400
# Step number: 191, time per step: 1.01, window size: 400
# [DEBUG] test_value=219.83509486169578, critical_value=35.19483799573105, len(BS_dist)=1, len(I_k)=400
# Found break for point 192 window size: 400
# Step number: 192, time per step: 1.01, window size: 400
# [DEBUG] test_value=217.6293249781163, critical_value=35.015303906262766, len(BS_dist)=1, len(I_k)=400
# Found break for point 193 window size: 400
# Step number: 193, time per step: 0.97, window size: 400
# [DEBUG] test_value=215.6816242203838, critical_value=33.96826386731951, len(BS_dist)=1, len(I_k)=400
# Found break for point 194 window size: 400
# Step number: 194, time per step: 1.03, window size: 400
# [DEBUG] test_value=215.65748669899529, critical_value=34.573488365598166, len(BS_dist)=1, len(I_k)=400
# Found break for point 195 window size: 400
# Step number: 195, time per step: 1.12, window size: 400
# [DEBUG] test_value=212.3636966949989, critical_value=35.85147016754049, len(BS_dist)=1, len(I_k)=400
# Found break for point 196 window size: 400
# Step number: 196, time per step: 1.16, window size: 400
# [DEBUG] test_value=212.3207103178977, critical_value=35.61303473669738, len(BS_dist)=1, len(I_k)=400
# Found break for point 197 window size: 400
# Step number: 197, time per step: 1.04, window size: 400
# [DEBUG] test_value=210.99272779831392, critical_value=36.895411358118, len(BS_dist)=1, len(I_k)=400
# Found break for point 198 window size: 400
# Step number: 198, time per step: 1.04, window size: 400
# [DEBUG] test_value=209.17078035549002, critical_value=35.41612183374849, len(BS_dist)=1, len(I_k)=400
# Found break for point 199 window size: 400
# Step number: 199, time per step: 1.00, window size: 400
# [DEBUG] test_value=209.90697043989496, critical_value=35.08312232287916, len(BS_dist)=1, len(I_k)=400
# Found break for point 200 window size: 400
# Step number: 200, time per step: 0.98, window size: 400
# [DEBUG] test_value=209.78710118541107, critical_value=34.49129036700235, len(BS_dist)=1, len(I_k)=400
# Found break for point 201 window size: 400
# Step number: 201, time per step: 1.00, window size: 400
# [DEBUG] test_value=208.7712281109798, critical_value=33.810609973570074, len(BS_dist)=1, len(I_k)=400
# Found break for point 202 window size: 400
# Step number: 202, time per step: 0.94, window size: 400
# [DEBUG] test_value=208.39265176006916, critical_value=35.35632734829447, len(BS_dist)=1, len(I_k)=400
# Found break for point 203 window size: 400
# Step number: 203, time per step: 0.97, window size: 400
# [DEBUG] test_value=208.0345393549394, critical_value=33.90875683357606, len(BS_dist)=1, len(I_k)=400
# Found break for point 204 window size: 400
# Step number: 204, time per step: 0.98, window size: 400
# [DEBUG] test_value=205.85298709200742, critical_value=33.97163110410666, len(BS_dist)=1, len(I_k)=400
# Found break for point 205 window size: 400
# Step number: 205, time per step: 1.14, window size: 400
# [DEBUG] test_value=204.9375933198628, critical_value=34.1519750918961, len(BS_dist)=1, len(I_k)=400
# Found break for point 206 window size: 400
# Step number: 206, time per step: 1.03, window size: 400
# [DEBUG] test_value=204.83323706735803, critical_value=34.030008605057375, len(BS_dist)=1, len(I_k)=400
# Found break for point 207 window size: 400
# Step number: 207, time per step: 1.15, window size: 400
# [DEBUG] test_value=204.72649408829488, critical_value=33.86098021898349, len(BS_dist)=1, len(I_k)=400
# Found break for point 208 window size: 400
# Step number: 208, time per step: 1.00, window size: 400
# [DEBUG] test_value=204.76548401694117, critical_value=33.76676040564962, len(BS_dist)=1, len(I_k)=400
# Found break for point 209 window size: 400
# Step number: 209, time per step: 1.05, window size: 400
# [DEBUG] test_value=205.12816490625755, critical_value=33.75391796684656, len(BS_dist)=1, len(I_k)=400
# Found break for point 210 window size: 400
# Step number: 210, time per step: 1.03, window size: 400
# [DEBUG] test_value=205.13810439283532, critical_value=34.51339552830815, len(BS_dist)=1, len(I_k)=400
# Found break for point 211 window size: 400
# Step number: 211, time per step: 1.06, window size: 400
# [DEBUG] test_value=205.5983017677096, critical_value=35.13470128841094, len(BS_dist)=1, len(I_k)=400
# Found break for point 212 window size: 400
# Step number: 212, time per step: 1.13, window size: 400
# [DEBUG] test_value=206.31168977565198, critical_value=34.64743123119814, len(BS_dist)=1, len(I_k)=400
# Found break for point 213 window size: 400
# Step number: 213, time per step: 1.03, window size: 400
# [DEBUG] test_value=206.61246527967774, critical_value=34.8425605605488, len(BS_dist)=1, len(I_k)=400
# Found break for point 214 window size: 400
# Step number: 214, time per step: 0.98, window size: 400
# [DEBUG] test_value=206.54172559947733, critical_value=33.66997563670669, len(BS_dist)=1, len(I_k)=400
# Found break for point 215 window size: 400
# Step number: 215, time per step: 1.01, window size: 400
# [DEBUG] test_value=206.42059321473528, critical_value=34.26262688686882, len(BS_dist)=1, len(I_k)=400
# Found break for point 216 window size: 400
# Step number: 216, time per step: 1.03, window size: 400
# [DEBUG] test_value=206.2129179317003, critical_value=34.522316830996594, len(BS_dist)=1, len(I_k)=400
# Found break for point 217 window size: 400
# Step number: 217, time per step: 0.94, window size: 400
# [DEBUG] test_value=206.4202038141168, critical_value=34.42275715846194, len(BS_dist)=1, len(I_k)=400
# Found break for point 218 window size: 400
# Step number: 218, time per step: 0.96, window size: 400
# [DEBUG] test_value=206.45842491914914, critical_value=34.78180788666787, len(BS_dist)=1, len(I_k)=400
# Found break for point 219 window size: 400
# Step number: 219, time per step: 1.00, window size: 400
# [DEBUG] test_value=206.87057334345218, critical_value=34.12446646644528, len(BS_dist)=1, len(I_k)=400
# Found break for point 220 window size: 400
# Step number: 220, time per step: 0.96, window size: 400
# [DEBUG] test_value=206.06483522115104, critical_value=35.01513686731536, len(BS_dist)=1, len(I_k)=400
# Found break for point 221 window size: 400
# Step number: 221, time per step: 0.99, window size: 400
# [DEBUG] test_value=206.34509029384014, critical_value=33.95238313980137, len(BS_dist)=1, len(I_k)=400
# Found break for point 222 window size: 400
# Step number: 222, time per step: 1.01, window size: 400
# [DEBUG] test_value=206.37880074860686, critical_value=35.314301433692556, len(BS_dist)=1, len(I_k)=400
# Found break for point 223 window size: 400
# Step number: 223, time per step: 0.98, window size: 400
# [DEBUG] test_value=205.5200744436014, critical_value=35.673411726342636, len(BS_dist)=1, len(I_k)=400
# Found break for point 224 window size: 400
# Step number: 224, time per step: 0.98, window size: 400
# [DEBUG] test_value=206.4071919336477, critical_value=35.296368812237716, len(BS_dist)=1, len(I_k)=400
# Found break for point 225 window size: 400
# Step number: 225, time per step: 1.07, window size: 400
# [DEBUG] test_value=204.91159691168173, critical_value=34.07003345148769, len(BS_dist)=1, len(I_k)=400
# Found break for point 226 window size: 400
# Step number: 226, time per step: 0.95, window size: 400
# [DEBUG] test_value=204.27335200700327, critical_value=34.10862949131752, len(BS_dist)=1, len(I_k)=400
# Found break for point 227 window size: 400
# Step number: 227, time per step: 1.04, window size: 400
# [DEBUG] test_value=204.57161010829532, critical_value=34.18452038963357, len(BS_dist)=1, len(I_k)=400
# Found break for point 228 window size: 400
# Step number: 228, time per step: 1.04, window size: 400
# [DEBUG] test_value=204.2470547834091, critical_value=34.80650504722288, len(BS_dist)=1, len(I_k)=400
# Found break for point 229 window size: 400
# Step number: 229, time per step: 1.09, window size: 400
# [DEBUG] test_value=203.9595904589014, critical_value=34.964637649416616, len(BS_dist)=1, len(I_k)=400
# Found break for point 230 window size: 400
# Step number: 230, time per step: 1.03, window size: 400
# [DEBUG] test_value=203.80527433148313, critical_value=35.344747005128, len(BS_dist)=1, len(I_k)=400
# Found break for point 231 window size: 400
# Step number: 231, time per step: 0.94, window size: 400
# [DEBUG] test_value=203.15192380662688, critical_value=33.840719092568165, len(BS_dist)=1, len(I_k)=400
# Found break for point 232 window size: 400
# Step number: 232, time per step: 1.01, window size: 400
# [DEBUG] test_value=202.6780513420531, critical_value=35.5791786778821, len(BS_dist)=1, len(I_k)=400
# Found break for point 233 window size: 400
# Step number: 233, time per step: 1.03, window size: 400
# [DEBUG] test_value=202.95807454258625, critical_value=33.89635557503076, len(BS_dist)=1, len(I_k)=400
# Found break for point 234 window size: 400
# Step number: 234, time per step: 1.00, window size: 400
# [DEBUG] test_value=202.20748782661963, critical_value=34.90220345043386, len(BS_dist)=1, len(I_k)=400
# Found break for point 235 window size: 400
# Step number: 235, time per step: 1.08, window size: 400
# [DEBUG] test_value=200.80390055620717, critical_value=35.29525820223048, len(BS_dist)=1, len(I_k)=400
# Found break for point 236 window size: 400
# Step number: 236, time per step: 1.04, window size: 400
# [DEBUG] test_value=200.4533584465073, critical_value=34.08998307193664, len(BS_dist)=1, len(I_k)=400
# Found break for point 237 window size: 400
# Step number: 237, time per step: 1.04, window size: 400
# [DEBUG] test_value=198.16037100756967, critical_value=34.65654230573639, len(BS_dist)=1, len(I_k)=400
# Found break for point 238 window size: 400
# Step number: 238, time per step: 1.01, window size: 400
# [DEBUG] test_value=196.81180194766318, critical_value=36.88303262424129, len(BS_dist)=1, len(I_k)=400
# Found break for point 239 window size: 400
# ...
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1260, time per step: 0.00, window size: 240
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1261, time per step: 0.00, window size: 239
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1262, time per step: 0.00, window size: 238
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1263, time per step: 0.00, window size: 237
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1264, time per step: 0.00, window size: 236
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1265, time per step: 0.00, window size: 235
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1266, time per step: 0.00, window size: 234
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1267, time per step: 0.00, window size: 233
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1268, time per step: 0.00, window size: 232
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1269, time per step: 0.00, window size: 231
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1270, time per step: 0.00, window size: 230
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1271, time per step: 0.00, window size: 229
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1272, time per step: 0.00, window size: 228
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1273, time per step: 0.00, window size: 227
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1274, time per step: 0.00, window size: 226
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1275, time per step: 0.00, window size: 225
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1276, time per step: 0.00, window size: 224
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1277, time per step: 0.00, window size: 223
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1278, time per step: 0.00, window size: 222
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1279, time per step: 0.00, window size: 221
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1280, time per step: 0.00, window size: 220
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1281, time per step: 0.00, window size: 219
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1282, time per step: 0.00, window size: 218
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1283, time per step: 0.00, window size: 217
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1284, time per step: 0.00, window size: 216
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1285, time per step: 0.00, window size: 215
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1286, time per step: 0.00, window size: 214
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1287, time per step: 0.00, window size: 213
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1288, time per step: 0.00, window size: 212
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1289, time per step: 0.00, window size: 211
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1290, time per step: 0.00, window size: 210
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1291, time per step: 0.00, window size: 209
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1292, time per step: 0.00, window size: 208
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1293, time per step: 0.00, window size: 207
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1294, time per step: 0.00, window size: 206
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Step number: 1295, time per step: 0.00, window size: 205
# Step number: 1296, time per step: 0.00, window size: 204
# Step number: 1297, time per step: 0.00, window size: 203
# Step number: 1298, time per step: 0.00, window size: 202
# Step number: 1299, time per step: 0.00, window size: 201
# Step number: 1300, time per step: 0.00, window size: 200
# Step number: 1301, time per step: 0.00, window size: 199
# Step number: 1302, time per step: 0.00, window size: 198
# Step number: 1303, time per step: 0.00, window size: 197
# Step number: 1304, time per step: 0.00, window size: 196
# Step number: 1305, time per step: 0.00, window size: 195
# Step number: 1306, time per step: 0.00, window size: 194
# Step number: 1307, time per step: 0.00, window size: 193
# Step number: 1308, time per step: 0.00, window size: 192
# Step number: 1309, time per step: 0.00, window size: 191
# Step number: 1310, time per step: 0.00, window size: 190
# Step number: 1311, time per step: 0.00, window size: 189
# Step number: 1312, time per step: 0.00, window size: 188
# Step number: 1313, time per step: 0.00, window size: 187
# Step number: 1314, time per step: 0.00, window size: 186
# Step number: 1315, time per step: 0.00, window size: 185
# Step number: 1316, time per step: 0.00, window size: 184
# Step number: 1317, time per step: 0.00, window size: 183
# Step number: 1318, time per step: 0.00, window size: 182
# Step number: 1319, time per step: 0.00, window size: 181
# Step number: 1320, time per step: 0.00, window size: 180
# Step number: 1321, time per step: 0.00, window size: 179
# Step number: 1322, time per step: 0.00, window size: 178
# Step number: 1323, time per step: 0.00, window size: 177
# Step number: 1324, time per step: 0.00, window size: 176
# Step number: 1325, time per step: 0.00, window size: 175
# Step number: 1326, time per step: 0.00, window size: 174
# Step number: 1327, time per step: 0.00, window size: 173
# Step number: 1328, time per step: 0.00, window size: 172
# Step number: 1329, time per step: 0.00, window size: 171
# Step number: 1330, time per step: 0.00, window size: 170
# Step number: 1331, time per step: 0.00, window size: 169
# Step number: 1332, time per step: 0.00, window size: 168
# Step number: 1333, time per step: 0.00, window size: 167
# Step number: 1334, time per step: 0.00, window size: 166
# Step number: 1335, time per step: 0.00, window size: 165
# Step number: 1336, time per step: 0.00, window size: 164
# Step number: 1337, time per step: 0.00, window size: 163
# Step number: 1338, time per step: 0.00, window size: 162
# Step number: 1339, time per step: 0.00, window size: 161
# Step number: 1340, time per step: 0.00, window size: 160
# Step number: 1341, time per step: 0.00, window size: 159
# Step number: 1342, time per step: 0.00, window size: 158
# Step number: 1343, time per step: 0.00, window size: 157
# Step number: 1344, time per step: 0.00, window size: 156
# Step number: 1345, time per step: 0.00, window size: 155
# Step number: 1346, time per step: 0.00, window size: 154
# Step number: 1347, time per step: 0.00, window size: 153
# Step number: 1348, time per step: 0.00, window size: 152
# Step number: 1349, time per step: 0.00, window size: 151
# Step number: 1350, time per step: 0.00, window size: 150
# Step number: 1351, time per step: 0.00, window size: 149
# Step number: 1352, time per step: 0.00, window size: 148
# Step number: 1353, time per step: 0.00, window size: 147
# Step number: 1354, time per step: 0.00, window size: 146
# Step number: 1355, time per step: 0.00, window size: 145
# Step number: 1356, time per step: 0.00, window size: 144
# Step number: 1357, time per step: 0.00, window size: 143
# Step number: 1358, time per step: 0.00, window size: 142
# Step number: 1359, time per step: 0.00, window size: 141
# Step number: 1360, time per step: 0.00, window size: 140
# Step number: 1361, time per step: 0.00, window size: 139
# Step number: 1362, time per step: 0.00, window size: 138
# Step number: 1363, time per step: 0.00, window size: 137
# Step number: 1364, time per step: 0.00, window size: 136
# Step number: 1365, time per step: 0.00, window size: 135
# Step number: 1366, time per step: 0.00, window size: 134
# Step number: 1367, time per step: 0.00, window size: 133
# Step number: 1368, time per step: 0.00, window size: 132
# Step number: 1369, time per step: 0.00, window size: 131
# Step number: 1370, time per step: 0.00, window size: 130
# Step number: 1371, time per step: 0.00, window size: 129
# Step number: 1372, time per step: 0.00, window size: 128
# Step number: 1373, time per step: 0.00, window size: 127
# Step number: 1374, time per step: 0.00, window size: 126
# Step number: 1375, time per step: 0.00, window size: 125
# Step number: 1376, time per step: 0.00, window size: 124
# Step number: 1377, time per step: 0.00, window size: 123
# Step number: 1378, time per step: 0.00, window size: 122
# Step number: 1379, time per step: 0.00, window size: 121
# Step number: 1380, time per step: 0.00, window size: 120
# Step number: 1381, time per step: 0.00, window size: 119
# Step number: 1382, time per step: 0.00, window size: 118
# Step number: 1383, time per step: 0.00, window size: 117
# Step number: 1384, time per step: 0.00, window size: 116
# Step number: 1385, time per step: 0.00, window size: 115
# Step number: 1386, time per step: 0.00, window size: 114
# Step number: 1387, time per step: 0.00, window size: 113
# Step number: 1388, time per step: 0.00, window size: 112
# Step number: 1389, time per step: 0.00, window size: 111
# Step number: 1390, time per step: 0.00, window size: 110
# Step number: 1391, time per step: 0.00, window size: 109
# Step number: 1392, time per step: 0.00, window size: 108
# Step number: 1393, time per step: 0.00, window size: 107
# Step number: 1394, time per step: 0.00, window size: 106
# Step number: 1395, time per step: 0.00, window size: 105
# Step number: 1396, time per step: 0.00, window size: 104
# Step number: 1397, time per step: 0.00, window size: 103
# Step number: 1398, time per step: 0.00, window size: 102
# Step number: 1399, time per step: 0.00, window size: 101
# Step number: 1400, time per step: 0.00, window size: 100
# Step number: 1401, time per step: 0.00, window size: 99
# Step number: 1402, time per step: 0.00, window size: 98
# Step number: 1403, time per step: 0.00, window size: 97
# Step number: 1404, time per step: 0.00, window size: 96
# Step number: 1405, time per step: 0.00, window size: 95
# Step number: 1406, time per step: 0.00, window size: 94
# Step number: 1407, time per step: 0.00, window size: 93
# Step number: 1408, time per step: 0.00, window size: 92
# Step number: 1409, time per step: 0.00, window size: 91
# Step number: 1410, time per step: 0.00, window size: 90
# Step number: 1411, time per step: 0.00, window size: 89
# Step number: 1412, time per step: 0.00, window size: 88
# Step number: 1413, time per step: 0.00, window size: 87
# Step number: 1414, time per step: 0.00, window size: 86
# Step number: 1415, time per step: 0.00, window size: 85
# Step number: 1416, time per step: 0.00, window size: 84
# Step number: 1417, time per step: 0.00, window size: 83
# Step number: 1418, time per step: 0.00, window size: 82
# Step number: 1419, time per step: 0.00, window size: 81
# Step number: 1420, time per step: 0.00, window size: 80
# Step number: 1421, time per step: 0.00, window size: 79
# Step number: 1422, time per step: 0.00, window size: 78
# Step number: 1423, time per step: 0.00, window size: 77
# Step number: 1424, time per step: 0.00, window size: 76
# Step number: 1425, time per step: 0.00, window size: 75
# Step number: 1426, time per step: 0.00, window size: 74
# Step number: 1427, time per step: 0.00, window size: 73
# Step number: 1428, time per step: 0.00, window size: 72
# Step number: 1429, time per step: 0.00, window size: 71
# Step number: 1430, time per step: 0.00, window size: 70
# Step number: 1431, time per step: 0.00, window size: 69
# Step number: 1432, time per step: 0.00, window size: 68
# Step number: 1433, time per step: 0.00, window size: 67
# Step number: 1434, time per step: 0.00, window size: 66
# Step number: 1435, time per step: 0.00, window size: 65
# Step number: 1436, time per step: 0.00, window size: 64
# Step number: 1437, time per step: 0.00, window size: 63
# Step number: 1438, time per step: 0.00, window size: 62
# Step number: 1439, time per step: 0.00, window size: 61
# Step number: 1440, time per step: 0.00, window size: 60
# Step number: 1441, time per step: 0.00, window size: 59
# Step number: 1442, time per step: 0.00, window size: 58
# Step number: 1443, time per step: 0.00, window size: 57
# Step number: 1444, time per step: 0.00, window size: 56
# Step number: 1445, time per step: 0.00, window size: 55
# Step number: 1446, time per step: 0.00, window size: 54
# Step number: 1447, time per step: 0.00, window size: 53
# Step number: 1448, time per step: 0.00, window size: 52
# Step number: 1449, time per step: 0.00, window size: 51
# Step number: 1450, time per step: 0.00, window size: 50
# Step number: 1451, time per step: 0.00, window size: 49
# Step number: 1452, time per step: 0.00, window size: 48
# Step number: 1453, time per step: 0.00, window size: 47
# Step number: 1454, time per step: 0.00, window size: 46
# Step number: 1455, time per step: 0.00, window size: 45
# Step number: 1456, time per step: 0.00, window size: 44
# Step number: 1457, time per step: 0.00, window size: 43
# Step number: 1458, time per step: 0.00, window size: 42
# Step number: 1459, time per step: 0.00, window size: 41
# Step number: 1460, time per step: 0.00, window size: 40
# Step number: 1461, time per step: 0.00, window size: 39
# Step number: 1462, time per step: 0.00, window size: 38
# Step number: 1463, time per step: 0.00, window size: 37
# Step number: 1464, time per step: 0.00, window size: 36
# Step number: 1465, time per step: 0.00, window size: 35
# Step number: 1466, time per step: 0.00, window size: 34
# Step number: 1467, time per step: 0.00, window size: 33
# Step number: 1468, time per step: 0.00, window size: 32
# Step number: 1469, time per step: 0.00, window size: 31
# Step number: 1470, time per step: 0.00, window size: 30
# Step number: 1471, time per step: 0.00, window size: 29
# Step number: 1472, time per step: 0.00, window size: 28
# Step number: 1473, time per step: 0.00, window size: 27
# Step number: 1474, time per step: 0.00, window size: 26
# Step number: 1475, time per step: 0.00, window size: 25
# Step number: 1476, time per step: 0.00, window size: 24
# Step number: 1477, time per step: 0.00, window size: 23
# Step number: 1478, time per step: 0.00, window size: 22
# Step number: 1479, time per step: 0.00, window size: 21
# Step number: 1480, time per step: 0.00, window size: 20
# Step number: 1481, time per step: 0.00, window size: 19
# Step number: 1482, time per step: 0.00, window size: 18
# Step number: 1483, time per step: 0.00, window size: 17
# Step number: 1484, time per step: 0.00, window size: 16
# Step number: 1485, time per step: 0.00, window size: 15
# Step number: 1486, time per step: 0.00, window size: 14
# Step number: 1487, time per step: 0.00, window size: 13
# Step number: 1488, time per step: 0.00, window size: 12
# Step number: 1489, time per step: 0.00, window size: 11
# Step number: 1490, time per step: 0.00, window size: 10
# Step number: 1491, time per step: 0.00, window size: 9
# Step number: 1492, time per step: 0.00, window size: 8
# Step number: 1493, time per step: 0.00, window size: 7
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Singular matrix
# [DEBUG] Interval too small for AR(3) process
# Time series length must be greater than AR order p.
# [DEBUG] Interval too small for AR(3) process
# Time series length must be greater than AR order p.
# [DEBUG] Interval too small for AR(3) process
# Time series length must be greater than AR order p.
# [DEBUG] Interval too small for AR(3) process
# Simulation number: 10
# Time: 1617.41 seconds
# Total tests: 295400

# %% [markdown]
# <h1>Combining the files</h1>

# %%
n_0 = 200
repeat_sim = 10
coeffs_name = "initial"
n_total = 1500
dataset_number = "1"
lengths_name = str(n_total)
filename_extra = f"_{dataset_number}_AR3_{lengths_name}_{coeffs_name}_data.csv"

# Getting names of all csv files
all_filenames=[]
for i in range(1,repeat_sim+1):
    filename = f"Arithmetic/{n_0}/" + str(i)+ filename_extra
    all_filenames.append(filename)
# Making a dataframe by concatinating name
df = pd.concat([pd.read_csv(f) for f in all_filenames ],axis=1)

#Deleting the duplicated date column
df = df.loc[:,~df.columns.duplicated()]
# Sorting the dataframe aphabatically
df = df.reindex(sorted(df.columns), axis=1)
df.to_csv(f'Arithmetic/{n_0}/combined_data.csv', index=False)

# %% [markdown]
# <h1>Constructing Confidence Intervals</h1>

# %%
filename = f'Arithmetic/{n_0}/combined_data.csv'
df= pd.read_csv(filename)
dates = df.Date

# %%
#CI plot
#Getting CIs for MLEs
colors = ["r", "g", "#ef8836"]
for beta in range(3):
    A= df.iloc[:,beta*repeat_sim+1:(beta+1)*repeat_sim+1]
    CI = norm_CI(A)
    mu = CI[0]
    lower = CI[1]
    upper = CI[2]
    plt.plot(dates,mu, color=colors[beta])
    plt.plot(dates,upper, color=colors[beta], linestyle = '--', alpha=.30)
    plt.plot(dates,lower, color=colors[beta], linestyle = '--', alpha=.30)
    plt.tick_params(axis="x", labelsize=20, labelrotation = 45)
    plt.tick_params(axis="y", labelsize=20)
    plt.ylim(-3, 3)
    filename = f"Arithmetic/{n_0}/B_{beta+1}_MLEs_confidence.png"
    plt.savefig(filename, transparent = True, bbox_inches="tight")
    plt.show()

# %%
# Fetching windows data from dataframe
A= df.iloc[:,-repeat_sim:]

#Getting CIs
CI = norm_CI(A)
mu = CI[0]
lower = CI[1]
upper = CI[2]
#CI plot
plt.plot(dates,mu, color='b')
plt.plot(dates,upper, color='b', linestyle = '--', alpha=.30)
plt.plot(dates,lower, color='b', linestyle = '--', alpha=.30)
plt.tick_params(axis="x", labelsize=20, labelrotation = 45)
plt.tick_params(axis="y", labelsize=20)
plt.savefig(f"Arithmetic/{n_0}/window_size.png", transparent = True,  bbox_inches="tight")

# %%
#Making a new column of MLEs in data 
col = df.loc[: , "MLEs_B_11":"MLEs_B_19"]
df['MLEs_B_1'] = col.mean(axis=1)

b2_col = df.loc[: , "MLEs_B_21":"MLEs_B_29"]
df['MLEs_B_2'] = b2_col.mean(axis=1)

b3_col = df.loc[: , "MLEs_B_31":"MLEs_B_39"]
df['MLEs_B_3'] = b3_col.mean(axis=1)

# %%
DT_N = df
nop=1 #number of periods ahead to forecast 

# Initialize y values
y = [0, 0, 0]

# Simulate AR(3) process using MLEs from DataFrame
for t in range(3, len(df)):
    # print(y[t-1])
    y_t = (
        # 1 +
        df.loc[t, 'MLEs_B_11'] * y[t-1] +   # y_{t-1}
        df.loc[t, 'MLEs_B_21'] * y[t-2] +   # y_{t-2}
        df.loc[t, 'MLEs_B_31'] * y[t-3]     # y_{t-3}
        + df.loc[t, 'epsilon']
    )
    # print(df.loc[t, 'MLEs_B2'])
    y.append(y_t)


dates = df.Date
plt.plot(dates, DT_N.N)
plt.plot(dates,y, linestyle='-', color = 'r')

# Drop the first 3 values to match the DataFrame index
plt.tick_params(axis="x", labelrotation = 45)
